# %% [markdown]
# Consider a ball of mass $m$ with horizontal coordinate $x$ rolling in a double-well potential $V(x) = x^4/4 - x^2/2$. (This is sometimes called the "sombrero" potential. Plot it to see why, for $x\in[-1.5,1.5]$.) This potential produces a force $f_{\text{hat}}(x) = -V'(x) = -x^3 + x$ on the rolling ball. Suppose the ball also has slight friction, so experiences a drag force $f_{\text{drag}}(\dot{x}) = -\nu \dot{x}$. With these forces we thus expect the ball to roll down the sides of the sombrero potential and settle in one of the two stable wells. However, this is boring, so instead we are going to shake the hat back and force periodically with a driving force $f_{\text{drive}}(t) = F\cos(\omega t)$. For small driving forces $F$, this should simply jiggle the ball back and forth at the bottom of one of the stable wells. Our task will be to explore what happens for larger driving forces $F$.

# %%
import numpy as np
import sympy as sp
import matplotlib.pyplot as plt

# %%
x = np.linspace(-1.5,1.5,1000)
plt.plot(x, temp(x,0.25))
plt.plot(x, sombrero(x))

# %%
@np.vectorize
def sombrero(x):
    return (x**4)/4 - (x**2)/2

@np.vectorize
def f_hat(x):
    return -1*(x**3)+x

@np.vectorize
def f_drag(x, v):
    return -v*x

#TEMP
@np.vectorize
def temp(x,v):
    return f_hat(x)# + f_drag(x,v)

#@np.vectorize
#def m_dotdot(x):

# %%
x,y = sp.symbols('x y')

# %%
f_hat =

# %%
acceleration = 1
velocity = 2

time = np.linspace(0,1,100)
dt = time[1]-time[0]

positions = [1]
prev_position = positions[0]
prev_velocity = 2

for time in time:
    new_velocity = prev_velocity + acceleration * dt
    new_position = prev_position + new_velocity * dt
    positions.append(new_position)
    prev_time = time
    prev_velocity = new_velocity
    pev_position = new_position
# Out:
# [1,
#  1.0203040506070808,
#  1.0204060810121416,
#  1.0205081114172023,
#  1.020610141822263,
#  1.0207121722273238,
#  1.0208142026323845,
#  1.020916233037445,
#  1.0210182634425058,
#  1.0211202938475665,
#  1.0212223242526273,
#  1.021324354657688,
#  1.0214263850627487,
#  1.0215284154678095,
#  1.02163044587287,
#  1.0217324762779307,
#  1.0218345066829915,
#  1.0219365370880522,
#  1.022038567493113,
#  1.0221405978981737,
#  1.0222426283032344,
#  1.022344658708295,
#  1.0224466891133557,
#  1.0225487195184164,
#  1.0226507499234772,
#  1.022752780328538,
#  1.0228548107335986,
#  1.0229568411386594,
#  1.0230588715437199,
#  1.0231609019487806,
#  1.0232629323538414,
#  1.023364962758902,
#  1.0234669931639628,
#  1.0235690235690236,
#  1.0236710539740843,
#  1.0237730843791448,
#  1.0238751147842056,
#  1.0239771451892663,
#  1.024079175594327,
#  1.0241812059993878,
#  1.0242832364044485,
#  1.0243852668095093,
#  1.0244872972145698,
#  1.0245893276196305,
#  1.0246913580246912,
#  1.024793388429752,
#  1.0248954188348127,
#  1.0249974492398735,
#  1.0250994796449342,
#  1.0252015100499947,
#  1.0253035404550555,
#  1.0254055708601162,
#  1.025507601265177,
#  1.0256096316702377,
#  1.0257116620752984,
#  1.0258136924803591,
#  1.0259157228854199,
#  1.0260177532904804,
#  1.0261197836955411,
#  1.0262218141006019,
#  1.0263238445056626,
#  1.0264258749107233,
#  1.026527905315784,
#  1.0266299357208448,
#  1.0267319661259053,
#  1.026833996530966,
#  1.0269360269360268,
#  1.0270380573410876,
#  1.0271400877461483,
#  1.027242118151209,
#  1.0273441485562698,
#  1.0274461789613303,
#  1.027548209366391,
#  1.0276502397714518,
#  1.0277522701765125,
#  1.0278543005815732,
#  1.027956330986634,
#  1.0280583613916947,
#  1.0281603917967552,
#  1.028262422201816,
#  1.0283644526068767,
#  1.0284664830119374,
#  1.0285685134169982,
#  1.028670543822059,
#  1.0287725742271197,
#  1.0288746046321802,
#  1.028976635037241,
#  1.0290786654423016,
#  1.0291806958473624,
#  1.0292827262524231,
#  1.0293847566574839,
#  1.0294867870625446,
#  1.029588817467605,
#  1.0296908478726658,
#  1.0297928782777266,
#  1.0298949086827873,
#  1.029996939087848,
#  1.0300989694929088,
#  1.0302009998979695,
#  1.03030303030303,
#  1.0304050607080908]

# %%
def r_plus(r, v, a)
